# %% [markdown]
# # Cleaning NHS sitreps data
#
# NHS England publish 'sitreps' on discharge delays at https://www.england.nhs.uk/statistics/statistical-work-areas/discharge-delays-acute-data/ - we need to:
#
# * Fetch the data files
# * Reshape the data
# * Combine it
# * Question it
#
# Let's start by importing the libraries we will need.

# %% [markdown]
# ## Import the libraries
#
# We need the `pandas` library to import a CSV, convert to a dataframe and reshape it, and the `requests` and `bs4` libraries for scraping the CSVs.

# %%
#import the pandas library and rename as pd
import pandas as pd
#requests for fetching webpages
import requests
#BeautifulSoup for scraping
from bs4 import BeautifulSoup
#regex for cleaning
import re

# %% [markdown]
# ## Import the data
#
# The data is published in two ways:
#
# * An XLSX file with 3 tables, and 5 sheets
# * A CSV file with the second table from that XLSX file in the first 127 columns, then the third table 131 columns in (after 4 empty columns)
#
# The column headings in both don't appear until row 4 (and row 5 for table 3 in the CSV), so we skip the first 3 rows in the import.
#
# For the CSV we also limit it to the first 127 columns. To do this we use the `usecols=` parameter, and generate a `range` of indices to give it. We have to add `*` to ["'unpick' the iterator"](https://stackoverflow.com/questions/35400861/pandas-read-table-usecols-error-with) returned by `range`.
#
# Here's the code for the CSV - but it isn't going to be much use...

# %%
#store the URL of one CSV file
csvurl = "https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/04/Daily-discharge-sitrep-monthly-data-webfile-March2023.csv"
#read it in, skipping the first 3 rows
#see https://stackoverflow.com/questions/35400861/pandas-read-table-usecols-error-with on how to specify a range of cols
df = pd.read_csv(csvurl, skiprows = 3,
                 skipinitialspace=True,
                 usecols=[*range(0,127)]) #import 127 cols only
#and show the first 5 rows
df.head(5)
# Out:
#   Unnamed: 0 Unnamed: 1                  Unnamed: 2  \
# 0        NaN        NaN                         NaN
# 1        NaN        NaN  ENGLAND (All Acute Trusts)
# 2        NaN        NaN             EAST OF ENGLAND
# 3        NaN        NaN                      LONDON
# 4        NaN        NaN                    MIDLANDS
#
#                                           01/03/2023  \
# 0  Number of patients who no longer meet the crit...
# 1                                              24374
# 2                                               2478
# 3                                               2887
# 4                                               4332
#
#                                Unnamed: 4  \
# 0  Number of patients discharged by 17:00
# 1                                    6702
# 2                                     991
# 3                                     864
# 4                                    1249
#
#                                           Unnamed: 5  \
# 0  Number of patients discharged between 17:01 an...
# 1                                               4443
# 2                                                453
# 3                                                608
# 4                                                826
#
#                                           Unnamed: 6  \
# 0  Number of patients remaining in hospital who n...
# 1                                              13229
# 2                                               1034
# 3                                               1415
# 4                                               2257
#
#                                           02/03/2023  \
# 0  Number of patients who no longer meet the crit...
# 1                                              24187
# 2                                               2431
# 3                                               2917
# 4                                               4411
#
#                                Unnamed: 8  \
# 0  Number of patients discharged by 17:00
# 1                                    6565
# 2                                     980
# 3                                     858
# 4                                    1231
#
#                                           Unnamed: 9  ...  \
# 0  Number of patients discharged between 17:01 an...  ...
# 1                                               4452  ...
# 2                                                472  ...
# 3                                                721  ...
# 4                                                749  ...
#
#                                         Unnamed: 117  \
# 0  Number of patients discharged between 17:01 an...
# 1                                               4519
# 2                                                458
# 3                                                612
# 4                                                926
#
#                                         Unnamed: 118  \
# 0  Number of patients remaining in hospital who n...
# 1                                              13306
# 2                                               1032
# 3                                               1449
# 4                                               2309
#
#                                           30/03/2023  \
# 0  Number of patients who no longer meet the crit...
# 1                                              24666
# 2                                               2340
# 3                                               3119
# 4                                               4378
#
#                              Unnamed: 120  \
# 0  Number of patients discharged by 17:00
# 1                                    7006
# 2                                     934
# 3                                     960
# 4                                    1257
#
#                                         Unnamed: 121  \
# 0  Number of patients discharged between 17:01 an...
# 1                                               4517
# 2                                                448
# 3                                                683
# 4                                                832
#
#                                         Unnamed: 122  \
# 0  Number of patients remaining in hospital who n...
# 1                                              13143
# 2                                                958
# 3                                               1476
# 4                                               2289
#
#                                           31/03/2023  \
# 0  Number of patients who no longer meet the crit...
# 1                                              25069
# 2                                               2352
# 3                                               3139
# 4                                               4367
#
#                              Unnamed: 124  \
# 0  Number of patients discharged by 17:00
# 1                                    7134
# 2                                     891
# 3                                     955
# 4                                    1292
#
#                                         Unnamed: 125  \
# 0  Number of patients discharged between 17:01 an...
# 1                                               4728
# 2                                                469
# 3                                                733
# 4                                                838
#
#                                         Unnamed: 126
# 0  Number of patients remaining in hospital who n...
# 1                                              13207
# 2                                                992
# 3                                               1451
# 4                                               2237
#
# [5 rows x 127 columns]

# %% [markdown]
# ### Import the XLSX
#
# ...Because for some reason only the last few months are provided as CSV files. For all 12 months we need to import the XLSX files.

# %%
#store the URL of one XLSX file
xlsxurl = "https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2022/08/Daily-discharge-sitrep-monthly-data-webfile-April2022-v2.xlsx"
#replace with the revised version that replaced it in August 2023
xlsxurl = "https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-April2022-revised.xlsx"
#read in the sheet called 'Table 2', skipping the first 3 rows
#see https://stackoverflow.com/questions/35400861/pandas-read-table-usecols-error-with on how to specify a range of cols
df = pd.read_excel(xlsxurl, skiprows = 3, sheet_name = 'Table 2')
#and show the first 5 rows
df.head(5)
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN  Notes: \n1. Due to disclosure risks, trust-lev...        NaN
# 1         NaN                                                NaN        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                                                NaN        NaN
# 4         NaN                                                NaN        NaN
#
#                 Unnamed: 3                                2022-04-01 00:00:00  \
# 0                      NaN  Number of patients who no longer meet the crit...
# 1  ENGLAND (Type 1 Trusts)                                              23511
# 2          EAST OF ENGLAND                                               2422
# 3                   LONDON                                               2429
# 4                 MIDLANDS                                               3893
#
#                       Unnamed: 5  \
# 0  Number of patients discharged
# 1                          10286
# 2                           1128
# 3                           1395
# 4                           1792
#
#                                           Unnamed: 6  \
# 0  Number of patients remaining in hospital who n...
# 1                                              13225
# 2                                               1294
# 3                                               1034
# 4                                               2101
#
#                                  2022-04-02 00:00:00  \
# 0  Number of patients who no longer meet the crit...
# 1                                              24029
# 2                                               2410
# 3                                               2499
# 4                                               4113
#
#                       Unnamed: 8  \
# 0  Number of patients discharged
# 1                          10801
# 2                           1106
# 3                           1499
# 4                           2093
#
#                                           Unnamed: 9  ...  \
# 0  Number of patients remaining in hospital who n...  ...
# 1                                              13228  ...
# 2                                               1304  ...
# 3                                               1000  ...
# 4                                               2020  ...
#
#                                          Unnamed: 84  \
# 0  Number of patients remaining in hospital who n...
# 1                                              12960
# 2                                               1203
# 3                                               1220
# 4                                               2072
#
#                                  2022-04-28 00:00:00  \
# 0  Number of patients who no longer meet the crit...
# 1                                              23905
# 2                                               2429
# 3                                               2685
# 4                                               4052
#
#                      Unnamed: 86  \
# 0  Number of patients discharged
# 1                          10830
# 2                           1269
# 3                           1502
# 4                           1951
#
#                                          Unnamed: 87  \
# 0  Number of patients remaining in hospital who n...
# 1                                              13075
# 2                                               1160
# 3                                               1183
# 4                                               2101
#
#                                  2022-04-29 00:00:00  \
# 0  Number of patients who no longer meet the crit...
# 1                                              23282
# 2                                               2357
# 3                                               2719
# 4                                               3872
#
#                      Unnamed: 89  \
# 0  Number of patients discharged
# 1                          10944
# 2                           1205
# 3                           1555
# 4                           2044
#
#                                          Unnamed: 90  \
# 0  Number of patients remaining in hospital who n...
# 1                                              12338
# 2                                               1152
# 3                                               1164
# 4                                               1828
#
#                                  2022-04-30 00:00:00  \
# 0  Number of patients who no longer meet the crit...
# 1                                              24682
# 2                                               2493
# 3                                               2903
# 4                                               4107
#
#                      Unnamed: 92  \
# 0  Number of patients discharged
# 1                          11862
# 2                           1268
# 3                           1768
# 4                           2043
#
#                                          Unnamed: 93
# 0  Number of patients remaining in hospital who n...
# 1                                              12820
# 2                                               1225
# 3                                               1135
# 4                                               2064
#
# [5 rows x 94 columns]

# %% [markdown]
# ## Remove rows
#
# We *did* have an extra couple lines here we don't need. The code block below dropped those - but the revised version that replaced it in August 2023 doesn't have this problem.

# %%
#axis = 0 means we want to drop rows
#drop rows 0 and 1 from
#df = df.drop(axis = 0, labels = [0,1])
#df

# %% [markdown]
# ## Remove columns
#
# We can remove the empty column at the start, though.

# %%
#axis = 1 means we want to drop columns
#drop column 0
df = df.drop(axis = 1, labels = df.keys()[0])
df
# Out:
#                                             Unnamed: 1 Unnamed: 2  \
# 0    Notes: \n1. Due to disclosure risks, trust-lev...        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 171                                         SOUTH WEST        RK9
# 172                                         SOUTH WEST        RN3
# 173                                         SOUTH WEST        RNZ
# 174                                         SOUTH WEST        RTE
# 175                                         SOUTH WEST        RVJ
#
#                                          Unnamed: 3  \
# 0                                               NaN
# 1                           ENGLAND (Type 1 Trusts)
# 2                                   EAST OF ENGLAND
# 3                                            LONDON
# 4                                          MIDLANDS
# ..                                              ...
# 171         UNIVERSITY HOSPITALS PLYMOUTH NHS TRUST
# 172    GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST
# 173                  SALISBURY NHS FOUNDATION TRUST
# 174  GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST
# 175                         NORTH BRISTOL NHS TRUST
#
#                                    2022-04-01 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                23511
# 2                                                 2422
# 3                                                 2429
# 4                                                 3893
# ..                                                 ...
# 171                                                301
# 172                                                218
# 173                                                127
# 174                                                280
# 175                                                284
#
#                         Unnamed: 5  \
# 0    Number of patients discharged
# 1                            10286
# 2                             1128
# 3                             1395
# 4                             1792
# ..                             ...
# 171                            110
# 172                            107
# 173                             31
# 174                             70
# 175                             86
#
#                                             Unnamed: 6  \
# 0    Number of patients remaining in hospital who n...
# 1                                                13225
# 2                                                 1294
# 3                                                 1034
# 4                                                 2101
# ..                                                 ...
# 171                                                191
# 172                                                111
# 173                                                 96
# 174                                                210
# 175                                                198
#
#                                    2022-04-02 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                24029
# 2                                                 2410
# 3                                                 2499
# 4                                                 4113
# ..                                                 ...
# 171                                                307
# 172                                                204
# 173                                                148
# 174                                                314
# 175                                                280
#
#                         Unnamed: 8  \
# 0    Number of patients discharged
# 1                            10801
# 2                             1106
# 3                             1499
# 4                             2093
# ..                             ...
# 171                            113
# 172                             94
# 173                             43
# 174                             93
# 175                             67
#
#                                             Unnamed: 9  \
# 0    Number of patients remaining in hospital who n...
# 1                                                13228
# 2                                                 1304
# 3                                                 1000
# 4                                                 2020
# ..                                                 ...
# 171                                                194
# 172                                                110
# 173                                                105
# 174                                                221
# 175                                                213
#
#                                    2022-04-03 00:00:00  ...  \
# 0    Number of patients who no longer meet the crit...  ...
# 1                                                19468  ...
# 2                                                 1884  ...
# 3                                                 2059  ...
# 4                                                 3151  ...
# ..                                                 ...  ...
# 171                                                250  ...
# 172                                                183  ...
# 173                                                135  ...
# 174                                                277  ...
# 175                                                257  ...
#
#                                            Unnamed: 84  \
# 0    Number of patients remaining in hospital who n...
# 1                                                12960
# 2                                                 1203
# 3                                                 1220
# 4                                                 2072
# ..                                                 ...
# 171                                                139
# 172                                                123
# 173                                                124
# 174                                                204
# 175                                                207
#
#                                    2022-04-28 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                23905
# 2                                                 2429
# 3                                                 2685
# 4                                                 4052
# ..                                                 ...
# 171                                                301
# 172                                                215
# 173                                                183
# 174                                                274
# 175                                                273
#
#                        Unnamed: 86  \
# 0    Number of patients discharged
# 1                            10830
# 2                             1269
# 3                             1502
# 4                             1951
# ..                             ...
# 171                            152
# 172                             95
# 173                             60
# 174                             85
# 175                             72
#
#                                            Unnamed: 87  \
# 0    Number of patients remaining in hospital who n...
# 1                                                13075
# 2                                                 1160
# 3                                                 1183
# 4                                                 2101
# ..                                                 ...
# 171                                                149
# 172                                                120
# 173                                                123
# 174                                                189
# 175                                                201
#
#                                    2022-04-29 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                23282
# 2                                                 2357
# 3                                                 2719
# 4                                                 3872
# ..                                                 ...
# 171                                                273
# 172                                                208
# 173                                                163
# 174                                                271
# 175                                                277
#
#                        Unnamed: 89  \
# 0    Number of patients discharged
# 1                            10944
# 2                             1205
# 3                             1555
# 4                             2044
# ..                             ...
# 171                            127
# 172                             81
# 173                             45
# 174                             72
# 175                             86
#
#                                            Unnamed: 90  \
# 0    Number of patients remaining in hospital who n...
# 1                                                12338
# 2                                                 1152
# 3                                                 1164
# 4                                                 1828
# ..                                                 ...
# 171                                                146
# 172                                                127
# 173                                                118
# 174                                                199
# 175                                                191
#
#                                    2022-04-30 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                24682
# 2                                                 2493
# 3                                                 2903
# 4                                                 4107
# ..                                                 ...
# 171                                                277
# 172                                                224
# 173                                                162
# 174                                                293
# 175                                                282
#
#                        Unnamed: 92  \
# 0    Number of patients discharged
# 1                            11862
# 2                             1268
# 3                             1768
# 4                             2043
# ..                             ...
# 171                            148
# 172                            109
# 173                             50
# 174                             89
# 175                             66
#
#                                            Unnamed: 93
# 0    Number of patients remaining in hospital who n...
# 1                                                12820
# 2                                                 1225
# 3                                                 1135
# 4                                                 2064
# ..                                                 ...
# 171                                                129
# 172                                                115
# 173                                                112
# 174                                                204
# 175                                                216
#
# [176 rows x 93 columns]

# %% [markdown]
# ## Clean up the headings
#
# The column headings are in three different places here:
#
# * The current headings contains the dates
# * Row 1 (5 in the original) contains the measurements
# * Row 11 (15 in the original) contains the headings for the first 3 columns
#
# We also have an empty row in row 14.
#
# To complicate things further, we have the same measures repeated for every day, creating almost 130 columns when really all we need is the following:
#
# * Region
# * STP code
# * STP name
# * Date
# * Measure (e.g. 'discharged by 17:00')
# * Number of patients

# %%
#show row 1, from the 4th item onwards
df.iloc[0][3:]
# Out:
# 2022-04-01 00:00:00    Number of patients who no longer meet the crit...
# Unnamed: 5                                 Number of patients discharged
# Unnamed: 6             Number of patients remaining in hospital who n...
# 2022-04-02 00:00:00    Number of patients who no longer meet the crit...
# Unnamed: 8                                 Number of patients discharged
#                                              ...
# Unnamed: 89                                Number of patients discharged
# Unnamed: 90            Number of patients remaining in hospital who n...
# 2022-04-30 00:00:00    Number of patients who no longer meet the crit...
# Unnamed: 92                                Number of patients discharged
# Unnamed: 93            Number of patients remaining in hospital who n...
# Name: 0, Length: 90, dtype: object

# %%
len(df.iloc[0])
# Out:
# 93

# %%
len(df)
# Out:
# 176

# %% [markdown]
# ## Work out the algorithm to reshape
#
# Here's what we need to do:
#
# *For* each row in the data:
#
# * Grab the 3 area cells and store against 3 keys
#
# Then *for* each cell after that:
#
# * Grab the column heading date if it is a date, or the last date if it's an 'Unnamed' column, and store against key 'date'
# * Grab the measure in row 1 and store against key 'measure'
# * Grab the value in the cell and store against the key 'number of patients'
#
# One challenge we have is that some keys are datetime objects - so we need to convert to string in the code.

# %%
#show the type of the 4th column heading (key)
print(type(df.keys()[3]))
#extract the first 10 characters which show the date
str(df.keys()[3])[:10]
# Out:
# <class 'datetime.datetime'>
# '2022-04-01'

# %%
#create an empty list to store a list of dicts
rows_list = []

#loop through each row, starting from row 12 because that's where the STP data begins
for i in range(11,len(df))[:10]:
  #print(i)
  #print(df.iloc[i][2])
  #the first, second and third cell should have the region, STP code and name
  #store each of those
  region = df.iloc[i][0]
  stpcode = df.iloc[i][1]
  stpname = df.iloc[i][2]
  #loop through the indices for the other 124 cells in the row
  for cell in range(3,len(df.iloc[0])):
    #start with an empty dict
    record = {}
    #print("cell", cell)
    #print("measure", df.iloc[0][cell])
    #store the row 1 heading at that position showing the measure
    measure = df.iloc[0][cell]
    #print("numofpatients", df.iloc[i][cell])
    #store the value in the cell related to that measure
    numberofpatients = df.iloc[i][cell]
    #print("col", df.keys()[cell])
    #If the column heading - the key - *doesn't* begin with 'Unnamed'
    if str(df.keys()[cell])[:7] != "Unnamed":
      #store it, because it will be the date
      #extract the first 10 chars because the others vary
      thisdate = str(df.keys()[cell])[:10]
      #otherwise it will still be the last date stored
    #print("thisdate",thisdate)
    #store all of that in the dict
    record['region'] = region
    record['stpcode'] = stpcode
    record['stpname'] = stpname
    record['date'] = thisdate
    record['measure'] = measure
    record['numberofpatients'] = numberofpatients
    print(record)
    #add to the list
    rows_list.append(record)
    #print("rows_list",rows_list)

#create a dataframe from that list of dicts
reshapeddf = pd.DataFrame(rows_list)
# Out:
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients':
HS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 1    NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 2    NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 3    NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# 4    NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# ..                                                 ...         ...
# 895        NHS SOUTH EAST LONDON INTEGRATED CARE BOARD  2022-04-29
# 896        NHS SOUTH EAST LONDON INTEGRATED CARE BOARD  2022-04-29
# 897        NHS SOUTH EAST LONDON INTEGRATED CARE BOARD  2022-04-30
# 898        NHS SOUTH EAST LONDON INTEGRATED CARE BOARD  2022-04-30
# 899        NHS SOUTH EAST LONDON INTEGRATED CARE BOARD  2022-04-30
#
#                                                measure  numberofpatients
# 0    Number of patients who no longer meet the crit...               426
# 1                        Number of patients discharged               230
# 2    Number of patients remaining in hospital who n...               196
# 3    Number of patients who no longer meet the crit...               440
# 4                        Number of patients discharged               208
# ..                                                 ...               ...
# 895                      Number of patients discharged               338
# 896  Number of patients remaining in hospital who n...               286
# 897  Number of patients who no longer meet the crit...               625
# 898                      Number of patients discharged               345
# 899  Number of patients remaining in hospital who n...               280
#
# [900 rows x 6 columns]

# %% [markdown]
# ## Add percentages
#
# Let's adjust the code to add new fields that show those three sub-figures (how many patients discharged at different times, and how many not discharged) as percentages rather than whole numbers.

# %%
#create an empty list to store a list of dicts
rows_list = []

#loop through each row, starting from row 12 because that's where the STP data begins
for i in range(11,len(df)):
  #print(i)
  #print(df.iloc[i][2])
  #the first, second and third cell should have the region, STP code and name
  #store each of those
  region = df.iloc[i][0]
  stpcode = df.iloc[i][1]
  stpname = df.iloc[i][2]
  #loop through the indices for the other 124 cells in the row
  for cell in range(3,len(df.iloc[0])):
    #start with an empty dict
    record = {}
    #print("cell", cell)
    #print("measure", df.iloc[0][cell])
    #store the row 1 heading at that position showing the measure
    measure = df.iloc[0][cell]
    print("numofpatients", df.iloc[i][cell], type(df.iloc[i][cell]))
    #store the value in the cell related to that measure
    numberofpatients = df.iloc[i][cell]
    #print("col", df.keys()[cell])
    #If the column heading - the key - *doesn't* begin with 'Unnamed'
    if str(df.keys()[cell])[:7] != "Unnamed":
      #store it, because it will be the date
      #extract the first 10 chars because the others vary
      thisdate = str(df.keys()[cell])[:10]
      #store the measure in that column too - as it's the total
      nolongermeetcriteria = numberofpatients
    #calculate the patients as a percentage of the total no longer meeting the criteria
    percof = int(numberofpatients)/int(nolongermeetcriteria)
    #print("thisdate",thisdate)
    #store all of that in the dict
    record['region'] = region
    record['stpcode'] = stpcode
    record['stpname'] = stpname
    record['date'] = thisdate
    record['measure'] = measure
    record['numberofpatients'] = numberofpatients
    #extra column showing figures as percentages
    record['percof_nolongermeetcriteria'] = percof
    print(record)
    #add to the list
    rows_list.append(record)
    #print("rows_list",rows_list)

#create a dataframe from that list of dicts
reshapeddf = pd.DataFrame(rows_list)
# Out:
# numofpatients 426 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 426, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 230 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients discharged', 'numberofpatients': 230, 'percof_nolongermeetcriteria': 0.539906103286385}
# numofpatients 196 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 196, 'percof_nolongermeetcriteria': 0.460093896713615}
# numofpatients 440 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 440, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 208 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients discharged', 'numberofpatients': 208, 'percof_nolongermeetcriteria': 0.4727272727272727}
# numofpatients 232 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 232, 'percof_nolongermeetcriteria': 0.5272727272727272}
# numofpatients 389 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 389, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 145 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients discharged', 'numberofpatients': 145, 'percof_nolongermeetcriteria': 0.37275064267352187}
# numofpatients 244 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 244, 'percof_nolongermeetcriteria': 0.6272493573264781}
# numofpatients 354 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 354, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 102 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients discharged', 'numberofpatients': 102, 'percof_nolongermeetcriteria': 0.288135593220339}
# numofpatients 252 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 252, 'percof_nolongermeetcriteria': 0.711864406779661}
# numofpatients 375 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 375, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 199 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients discharged', 'numberofpatients': 199, 'percof_nolongermeetcriteria': 0.5306666666666666}
# numofpatients 176 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 176, 'percof_nolongermeetcriteria': 0.4693333333333333}
# numofpatients 392 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 392, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 213 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients discharged', 'numberofpatients': 213, 'percof_nolongermeetcriteria': 0.5433673469387755}
# numofpatients 179 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 179, 'percof_nolongermeetcriteria': 0.45663265306122447}
# numofpatients 382 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 382, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 228 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients discharged', 'numberofpatients': 228, 'percof_nolongermeetcriteria': 0.5968586387434555}
# numofpatients 154 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 154, 'percof_nolongermeetcriteria': 0.4031413612565445}
# numofpatients 382 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 382, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 223 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients discharged', 'numberofpatients': 223, 'percof_nolongermeetcriteria': 0.5837696335078534}
# numofpatients 159 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 159, 'percof_nolongermeetcriteria': 0.4162303664921466}
# numofpatients 407 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 407, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 238 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients discharged', 'numberofpatients': 238, 'percof_nolongermeetcriteria': 0.5847665847665847}
# numofpatients 169 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 169, 'percof_nolongermeetcriteria': 0.4152334152334152}
# numofpatients 386 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 386, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 120 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients discharged', 'numberofpatients': 120, 'percof_nolongermeetcriteria': 0.31088082901554404}
# numofpatients 266 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 266, 'percof_nolongermeetcriteria': 0.689119170984456}
# numofpatients 330 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 330, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 93 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients discharged', 'numberofpatients': 93, 'percof_nolongermeetcriteria': 0.2818181818181818}
# numofpatients 237 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 237, 'percof_nolongermeetcriteria': 0.7181818181818181}
# numofpatients 365 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 365, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 187 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients discharged', 'numberofpatients': 187, 'percof_nolongermeetcriteria': 0.5123287671232877}
# numofpatients 178 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 178, 'percof_nolongermeetcriteria': 0.4876712328767123}
# numofpatients 392 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 392, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 246 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients discharged', 'numberofpatients': 246, 'percof_nolongermeetcriteria': 0.6275510204081632}
# numofpatients 146 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 146, 'percof_nolongermeetcriteria': 0.37244897959183676}
# numofpatients 360 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 360, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 239 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients discharged', 'numberofpatients': 239, 'percof_nolongermeetcriteria': 0.6638888888888889}
# numofpatients 121 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 121, 'percof_nolongermeetcriteria': 0.33611111111111114}
# numofpatients 408 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 408, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 262 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients discharged', 'numberofpatients': 262, 'percof_nolongermeetcriteria': 0.6421568627450981}
# numofpatients 146 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 146, 'percof_nolongermeetcriteria': 0.35784313725490197}
# numofpatients 431 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 431, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 173 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients discharged', 'numberofpatients': 173, 'percof_nolongermeetcriteria': 0.4013921113689095}
# numofpatients 258 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 258, 'percof_nolongermeetcriteria': 0.5986078886310905}
# numofpatients 405 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 405, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 98 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients discharged', 'numberofpatients': 98, 'percof_nolongermeetcriteria': 0.2419753086419753}
# numofpatients 307 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 307, 'percof_nolongermeetcriteria': 0.7580246913580246}
# numofpatients 373 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 373, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 116 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients discharged', 'numberofpatients': 116, 'percof_nolongermeetcriteria': 0.3109919571045576}
# numofpatients 257 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 257, 'percof_nolongermeetcriteria': 0.6890080428954424}
# numofpatients 361 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 361, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 122 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients discharged', 'numberofpatients': 122, 'percof_nolongermeetcriteria': 0.3379501385041551}
# numofpatients 239 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 239, 'percof_nolongermeetcriteria': 0.6620498614958449}
# numofpatients 348 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 348, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 175 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients discharged', 'numberofpatients': 175, 'percof_nolongermeetcriteria': 0.5028735632183908}
# numofpatients 173 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 173, 'percof_nolongermeetcriteria': 0.49712643678160917}
# numofpatients 349 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 349, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 220 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients discharged', 'numberofpatients': 220, 'percof_nolongermeetcriteria': 0.6303724928366762}
# numofpatients 129 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 129, 'percof_nolongermeetcriteria': 0.36962750716332377}
# numofpatients 341 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 341, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 224 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients discharged', 'numberofpatients': 224, 'percof_nolongermeetcriteria': 0.656891495601173}
# numofpatients 117 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 117, 'percof_nolongermeetcriteria': 0.34310850439882695}
# numofpatients 390 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 390, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 275 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients discharged', 'numberofpatients': 275, 'percof_nolongermeetcriteria': 0.7051282051282052}
# numofpatients 115 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 115, 'percof_nolongermeetcriteria': 0.2948717948717949}
# numofpatients 348 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 348, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 145 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients discharged', 'numberofpatients': 145, 'percof_nolongermeetcriteria': 0.4166666666666667}
# numofpatients 203 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 203, 'percof_nolongermeetcriteria': 0.5833333333333334}
# numofpatients 340 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 340, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 107 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients discharged', 'numberofpatients': 107, 'percof_nolongermeetcriteria': 0.31470588235294117}
# numofpatients 233 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 233, 'percof_nolongermeetcriteria': 0.6852941176470588}
# numofpatients 347 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 347, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 215 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients discharged', 'numberofpatients': 215, 'percof_nolongermeetcriteria': 0.6195965417867435}
# numofpatients 132 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 132, 'percof_nolongermeetcriteria': 0.3804034582132565}
# numofpatients 354 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 354, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 231 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients discharged', 'numberofpatients': 231, 'percof_nolongermeetcriteria': 0.652542372881356}
# numofpatients 123 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 123, 'percof_nolongermeetcriteria': 0.3474576271186441}
# numofpatients 338 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 338, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 219 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients discharged', 'numberofpatients': 219, 'percof_nolongermeetcriteria': 0.6479289940828402}
# numofpatients 119 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 119, 'percof_nolongermeetcriteria': 0.3520710059171598}
# numofpatients 339 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 339, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 219 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients discharged', 'numberofpatients': 219, 'percof_nolongermeetcriteria': 0.6460176991150443}
# numofpatients 120 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 120, 'percof_nolongermeetcriteria': 0.35398230088495575}
# numofpatients 404 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 404, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 232 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients discharged', 'numberofpatients': 232, 'percof_nolongermeetcriteria': 0.5742574257425742}
# numofpatients 172 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QUE', 'stpname': 'NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 172, 'percof_nolongermeetcriteria': 0.42574257425742573}
# numofpatients 553 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 553, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 227 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients discharged', 'numberofpatients': 227, 'percof_nolongermeetcriteria': 0.4104882459312839}
# numofpatients 326 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 326, 'percof_nolongermeetcriteria': 0.5895117540687161}
# numofpatients 625 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 625, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 242 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients discharged', 'numberofpatients': 242, 'percof_nolongermeetcriteria': 0.3872}
# numofpatients 383 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 383, 'percof_nolongermeetcriteria': 0.6128}
# numofpatients 505 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 505, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 185 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients discharged', 'numberofpatients': 185, 'percof_nolongermeetcriteria': 0.36633663366336633}
# numofpatients 320 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 320, 'percof_nolongermeetcriteria': 0.6336633663366337}
# numofpatients 448 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 448, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 131 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients discharged', 'numberofpatients': 131, 'percof_nolongermeetcriteria': 0.2924107142857143}
# numofpatients 317 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 0.7075892857142857}
# numofpatients 467 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 467, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 179 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients discharged', 'numberofpatients': 179, 'percof_nolongermeetcriteria': 0.38329764453961457}
# numofpatients 288 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 288, 'percof_nolongermeetcriteria': 0.6167023554603854}
# numofpatients 527 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 527, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 268 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients discharged', 'numberofpatients': 268, 'percof_nolongermeetcriteria': 0.50853889943074}
# numofpatients 259 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 259, 'percof_nolongermeetcriteria': 0.49146110056925996}
# numofpatients 508 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 508, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 230 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients discharged', 'numberofpatients': 230, 'percof_nolongermeetcriteria': 0.452755905511811}
# numofpatients 278 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 278, 'percof_nolongermeetcriteria': 0.547244094488189}
# numofpatients 532 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 532, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 267 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients discharged', 'numberofpatients': 267, 'percof_nolongermeetcriteria': 0.5018796992481203}
# numofpatients 265 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 265, 'percof_nolongermeetcriteria': 0.4981203007518797}
# numofpatients 586 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 586, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 213 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients discharged', 'numberofpatients': 213, 'percof_nolongermeetcriteria': 0.363481228668942}
# numofpatients 373 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 373, 'percof_nolongermeetcriteria': 0.636518771331058}
# numofpatients 395 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 395, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 134 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients discharged', 'numberofpatients': 134, 'percof_nolongermeetcriteria': 0.3392405063291139}
# numofpatients 261 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 261, 'percof_nolongermeetcriteria': 0.660759493670886}
# numofpatients 450 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 450, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 139 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients discharged', 'numberofpatients': 139, 'percof_nolongermeetcriteria': 0.3088888888888889}
# numofpatients 311 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 311, 'percof_nolongermeetcriteria': 0.6911111111111111}
# numofpatients 523 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 523, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 235 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients discharged', 'numberofpatients': 235, 'percof_nolongermeetcriteria': 0.44933078393881454}
# numofpatients 288 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 288, 'percof_nolongermeetcriteria': 0.5506692160611855}
# numofpatients 540 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 540, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 233 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients discharged', 'numberofpatients': 233, 'percof_nolongermeetcriteria': 0.43148148148148147}
# numofpatients 307 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 307, 'percof_nolongermeetcriteria': 0.5685185185185185}
# numofpatients 552 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 552, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 230 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients discharged', 'numberofpatients': 230, 'percof_nolongermeetcriteria': 0.4166666666666667}
# numofpatients 322 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 322, 'percof_nolongermeetcriteria': 0.5833333333333334}
# numofpatients 412 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 412, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 258 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients discharged', 'numberofpatients': 258, 'percof_nolongermeetcriteria': 0.6262135922330098}
# numofpatients 154 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 154, 'percof_nolongermeetcriteria': 0.3737864077669903}
# numofpatients 449 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 449, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 304 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients discharged', 'numberofpatients': 304, 'percof_nolongermeetcriteria': 0.6770601336302895}
# numofpatients 145 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-16', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 145, 'percof_nolongermeetcriteria': 0.32293986636971045}
# numofpatients 402 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 402, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 113 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients discharged', 'numberofpatients': 113, 'percof_nolongermeetcriteria': 0.2810945273631841}
# numofpatients 289 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-17', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 289, 'percof_nolongermeetcriteria': 0.7189054726368159}
# numofpatients 462 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 462, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 124 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients discharged', 'numberofpatients': 124, 'percof_nolongermeetcriteria': 0.2683982683982684}
# numofpatients 338 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-18', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 338, 'percof_nolongermeetcriteria': 0.7316017316017316}
# numofpatients 433 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 433, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 145 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients discharged', 'numberofpatients': 145, 'percof_nolongermeetcriteria': 0.3348729792147806}
# numofpatients 288 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-19', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 288, 'percof_nolongermeetcriteria': 0.6651270207852193}
# numofpatients 480 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 480, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 198 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients discharged', 'numberofpatients': 198, 'percof_nolongermeetcriteria': 0.4125}
# numofpatients 282 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 282, 'percof_nolongermeetcriteria': 0.5875}
# numofpatients 550 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 550, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 249 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients discharged', 'numberofpatients': 249, 'percof_nolongermeetcriteria': 0.4527272727272727}
# numofpatients 301 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 301, 'percof_nolongermeetcriteria': 0.5472727272727272}
# numofpatients 392 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QMM', 'stpname': 'NHS NORFOLK AND WAVENEY INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 392, 'percof_nolongermeetcriteria': 1.0}
# ...
# numofpatients 225 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QM7', 'stpname': 'NHS HERTFORDSHIRE AND WEST ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients discharged', 'numberofpatients': 225, 'percof_nolongermeetcriteria': 0.5079006772009029}
# numofpatients 218 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QM7', 'stpname': 'NHS HERTFORDSHIRE AND WEST ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 218, 'percof_nolongermeetcriteria': 0.49209932279909707}
# numofpatients 471 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QM7', 'stpname': 'NHS HERTFORDSHIRE AND WEST ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 471, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 244 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QM7', 'stpname': 'NHS HERTFORDSHIRE AND WEST ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients discharged', 'numberofpatients': 244, 'percof_nolongermeetcriteria': 0.5180467091295117}
# numofpatients 227 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QM7', 'stpname': 'NHS HERTFORDSHIRE AND WEST ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 227, 'percof_nolongermeetcriteria': 0.4819532908704883}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 53 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients discharged', 'numberofpatients': 53, 'percof_nolongermeetcriteria': 0.21991701244813278}
# numofpatients 188 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 188, 'percof_nolongermeetcriteria': 0.7800829875518672}
# numofpatients 111 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 111, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 0 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients discharged', 'numberofpatients': 0, 'percof_nolongermeetcriteria': 0.0}
# numofpatients 111 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 111, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 67 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 67, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 0 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients discharged', 'numberofpatients': 0, 'percof_nolongermeetcriteria': 0.0}
# numofpatients 67 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-03', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 67, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 24 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients discharged', 'numberofpatients': 24, 'percof_nolongermeetcriteria': 0.0995850622406639}
# numofpatients 217 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-04', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 217, 'percof_nolongermeetcriteria': 0.9004149377593361}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 44 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients discharged', 'numberofpatients': 44, 'percof_nolongermeetcriteria': 0.1825726141078838}
# numofpatients 197 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-05', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 197, 'percof_nolongermeetcriteria': 0.8174273858921162}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 58 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients discharged', 'numberofpatients': 58, 'percof_nolongermeetcriteria': 0.24066390041493776}
# numofpatients 183 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-06', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 183, 'percof_nolongermeetcriteria': 0.7593360995850622}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 51 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients discharged', 'numberofpatients': 51, 'percof_nolongermeetcriteria': 0.21161825726141079}
# numofpatients 190 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-07', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 190, 'percof_nolongermeetcriteria': 0.7883817427385892}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 59 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients discharged', 'numberofpatients': 59, 'percof_nolongermeetcriteria': 0.24481327800829875}
# numofpatients 182 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-08', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 182, 'percof_nolongermeetcriteria': 0.7551867219917012}
# numofpatients 242 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 242, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 75 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients discharged', 'numberofpatients': 75, 'percof_nolongermeetcriteria': 0.30991735537190085}
# numofpatients 167 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-09', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 167, 'percof_nolongermeetcriteria': 0.6900826446280992}
# numofpatients 157 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 157, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 25 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients discharged', 'numberofpatients': 25, 'percof_nolongermeetcriteria': 0.1592356687898089}
# numofpatients 132 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-10', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 132, 'percof_nolongermeetcriteria': 0.8407643312101911}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 19 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients discharged', 'numberofpatients': 19, 'percof_nolongermeetcriteria': 0.07883817427385892}
# numofpatients 222 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-11', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 222, 'percof_nolongermeetcriteria': 0.921161825726141}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 40 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients discharged', 'numberofpatients': 40, 'percof_nolongermeetcriteria': 0.16597510373443983}
# numofpatients 201 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-12', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 201, 'percof_nolongermeetcriteria': 0.8340248962655602}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 59 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients discharged', 'numberofpatients': 59, 'percof_nolongermeetcriteria': 0.24481327800829875}
# numofpatients 182 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-13', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 182, 'percof_nolongermeetcriteria': 0.7551867219917012}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 69 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients discharged', 'numberofpatients': 69, 'percof_nolongermeetcriteria': 0.2863070539419087}
# numofpatients 172 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-14', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 172, 'percof_nolongermeetcriteria': 0.7136929460580913}
# numofpatients 241 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# numofpatients 69 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients discharged', 'numberofpatients': 69, 'percof_nolongermeetcriteria': 0.2863070539419087}
# numofpatients 172 <class 'int'>
# {'region': 'EAST OF ENGLAND', 'stpcode': 'QH8', 'stpname': 'NHS MID AND SOUTH ESSEX INTEGRATED CARE BOARD', 'date': '2022-04-15', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 172, 'percof_nolongermeetcriteria': 0.7136929460580913}
# numofpatients 0 <class 'int'>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-48-1db65a57b455> in <cell line: 5>()
#      31       nolongermeetcriteria = numberofpatients
#      32     #calculate the patients as a percentage of the total no longer meeting the criteria
# ---> 33     percof = int(numberofpatients)/int(nolongermeetcriteria)
#      34     #print("thisdate",thisdate)
#      35     #store all of that in the dict
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Handle division by zero and empty rows
#
# Where an organisation has not provided figures that is recorded as zero, which causes an error.
#
# We also need to look out for empty rows

# %%
nolongermeetcriteria != 0 and not '0'
# Out:
# False

# %%
#create an empty list to store a list of dicts
rows_list = []

#loop through each row, starting from row 12 because that's where the STP data begins
for i in range(11,len(df)):
  #print(i)
  #print(df.iloc[i][2])
  #the first, second and third cell should have the region, STP code and name
  #store each of those
  region = df.iloc[i][0]
  stpcode = df.iloc[i][1]
  stpname = df.iloc[i][2]
  #if it's not an empty cell or header cell
  print("region", region)
  if region != "Region" and not pd.isna(region):
    #loop through the indices for the other 124 cells in the row
    for cell in range(3,len(df.iloc[0])):
      #start with an empty dict
      record = {}
      #print("cell", cell)
      print("measure", df.iloc[0][cell])
      #store the row 1 heading at that position showing the measure
      measure = df.iloc[0][cell]
      print("numofpatients", df.iloc[i][cell], type(df.iloc[i][cell]))
      #store the value in the cell related to that measure
      numberofpatients = df.iloc[i][cell]
      #print("col", df.keys()[cell])
      #If the column heading - the key - *doesn't* begin with 'Unnamed'
      if str(df.keys()[cell])[:7] != "Unnamed":
        #store it, because it will be the date
        #extract the first 10 chars because the others vary
        thisdate = str(df.keys()[cell])[:10]
        #store the measure in that column too - as it's the total
      if measure == 'Number of patients who no longer meet the criteria to reside':
        nolongermeetcriteria = numberofpatients
        #we check that the total patients is not zero, which would cause an error
      #print("IS IT ZERO",nolongermeetcriteria)
      if nolongermeetcriteria != 0:
        print("NOT ZERO")
        #calculate the patients as a percentage of the total no longer meeting the criteria
        percof = int(numberofpatients)/int(nolongermeetcriteria)
      #if if is zero then we store the lack of data
      else:
        print("ZERO")
        percof = 'no data'
      #print("thisdate",thisdate)
      #store all of that in the dict
      record['region'] = region
      record['code'] = stpcode
      record['org'] = stpname
      record['date'] = thisdate
      record['measure'] = measure
      record['numberofpatients'] = numberofpatients
      #extra column showing figures as percentages
      record['percof_nolongermeetcriteria'] = percof
      print(record)
      #add to the list
      rows_list.append(record)
      #print("rows_list",rows_list)

#create a dataframe from that list of dicts
reshapeddf = pd.DataFrame(rows_list)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-20', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 328, 'percof_nolongermeetcriteria': 0.4719424460431655}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 724 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 724, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 415 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients discharged', 'numberofpatients': 415, 'percof_nolongermeetcriteria': 0.5732044198895028}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 309 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-21', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 309, 'percof_nolongermeetcriteria': 0.42679558011049723}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 642 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 642, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 308 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients discharged', 'numberofpatients': 308, 'percof_nolongermeetcriteria': 0.4797507788161994}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 334 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-22', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 334, 'percof_nolongermeetcriteria': 0.5202492211838006}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 585 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 585, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 278 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients discharged', 'numberofpatients': 278, 'percof_nolongermeetcriteria': 0.4752136752136752}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 307 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-23', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 307, 'percof_nolongermeetcriteria': 0.5247863247863248}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 523 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 523, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 178 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients discharged', 'numberofpatients': 178, 'percof_nolongermeetcriteria': 0.3403441682600382}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 345 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-24', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 345, 'percof_nolongermeetcriteria': 0.6596558317399618}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 599 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 599, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 220 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients discharged', 'numberofpatients': 220, 'percof_nolongermeetcriteria': 0.3672787979966611}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 379 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-25', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 379, 'percof_nolongermeetcriteria': 0.6327212020033389}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 599 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 599, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 253 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients discharged', 'numberofpatients': 253, 'percof_nolongermeetcriteria': 0.42237061769616024}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 346 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-26', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 346, 'percof_nolongermeetcriteria': 0.5776293823038398}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 621 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 621, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 252 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients discharged', 'numberofpatients': 252, 'percof_nolongermeetcriteria': 0.4057971014492754}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 369 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-27', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 369, 'percof_nolongermeetcriteria': 0.5942028985507246}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 610 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 610, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 293 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients discharged', 'numberofpatients': 293, 'percof_nolongermeetcriteria': 0.48032786885245904}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 317 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-28', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 0.519672131147541}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 635 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 635, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 317 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients discharged', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 0.49921259842519683}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 318 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-29', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 318, 'percof_nolongermeetcriteria': 0.5007874015748032}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 614 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 614, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 317 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients discharged', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 0.5162866449511401}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 297 <class 'int'>
# NOT ZERO
# {'region': 'NORTH WEST', 'code': 'QE1', 'org': 'NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD', 'date': '2022-04-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 297, 'percof_nolongermeetcriteria': 0.4837133550488599}
# region SOUTH EAST
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 835 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH EAST', 'code': 'QKS', 'org': 'NHS KENT AND MEDWAY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 835, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 348 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH EAST', 'code': 'QKS', 'org': 'NHS KENT AND MEDWAY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients discharged', 'numberofpatients': 348, 'percof_nolongermeetcriteria': 0.4167664670658683}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 487 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH EAST', 'code': 'QKS', 'org': 'NHS KENT AND MEDWAY INTEGRATED CARE BOARD', 'date': '2022-04-01', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 487, 'percof_nolongermeetcriteria': 0.5832335329341317}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 771 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH EAST', 'code': 'QKS', 'org': 'NHS KENT AND MEDWAY INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 771, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 351 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH EAST', 'code': 'QKS', 'org': 'NHS KENT AND MEDWAY INTEGRATED CARE BOARD', 'date': '2022-04-02', 'measure': 'Number of patients discharged', 'numberofpatients':
<class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-13', 'measure': 'Number of patients discharged', 'numberofpatients': 59, 'percof_nolongermeetcriteria': 0.24481327800829875}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 182 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-13', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 182, 'percof_nolongermeetcriteria': 0.7551867219917012}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 241 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-14', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 69 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-14', 'measure': 'Number of patients discharged', 'numberofpatients': 69, 'percof_nolongermeetcriteria': 0.2863070539419087}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 172 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-14', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 172, 'percof_nolongermeetcriteria': 0.7136929460580913}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 241 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-15', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 69 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-15', 'measure': 'Number of patients discharged', 'numberofpatients': 69, 'percof_nolongermeetcriteria': 0.2863070539419087}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 172 <class 'int'>
# NOT ZERO
# {'region': 'EAST OF ENGLAND', 'code': 'RAJ', 'org': 'MID AND SOUTH ESSEX NHS FOUNDATION TRUST', 'date': '2022-04-15', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 172, 'percof_nolongermeetcriteria': 0.7136929460580913}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients - <class 'str'>
# NOT ZERO
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-93b7d882280a> in <cell line: 5>()
#      39         print("NOT ZERO")
#      40         #calculate the patients as a percentage of the total no longer meeting the criteria
# ---> 41         percof = int(numberofpatients)/int(nolongermeetcriteria)
#      42       #if if is zero then we store the lack of data
#      43       else:
#
# ValueError: invalid literal for int() with base 10: '-'

# %% [markdown]
# ## Handle dashes entered as data
#
# The revised data now includes cells where a dash has been used instead of a zero or number.
#
# We can check the latest value stored in the variable `nolongermeetcriteria`

# %%
nolongermeetcriteria
# Out:
# '-'

# %%
#this still returns True against the error-prevention test
nolongermeetcriteria != 0
# Out:
# True

# %%
#So we will need to add this one
nolongermeetcriteria == '-'
# Out:
# True

# %%
#Or this one
type(nolongermeetcriteria) == str
# Out:
# True

# %%
#We can extend the test to this
nolongermeetcriteria != 0 and not '-'
# Out:
# False

# %%
#We can extend the test to this
'-' != 0 and not '-'
# Out:
# False

# %%
#create an empty list to store a list of dicts
rows_list = []

#loop through each row, starting from row 12 because that's where the STP data begins
for i in range(11,len(df)):
  #print(i)
  #print(df.iloc[i][2])
  #the first, second and third cell should have the region, STP code and name
  #store each of those
  region = df.iloc[i][0]
  stpcode = df.iloc[i][1]
  stpname = df.iloc[i][2]
  #if it's not an empty cell or header cell
  print("region", region)
  if region != "Region" and not pd.isna(region):
    #loop through the indices for the other 124 cells in the row
    for cell in range(3,len(df.iloc[0])):
      #start with an empty dict
      record = {}
      #print("cell", cell)
      print("measure", df.iloc[0][cell])
      #store the row 1 heading at that position showing the measure
      measure = df.iloc[0][cell]
      print("numofpatients", df.iloc[i][cell], type(df.iloc[i][cell]))
      #store the value in the cell related to that measure
      numberofpatients = df.iloc[i][cell]
      #print("col", df.keys()[cell])
      #If the column heading - the key - *doesn't* begin with 'Unnamed'
      if str(df.keys()[cell])[:7] != "Unnamed":
        #store it, because it will be the date
        #extract the first 10 chars because the others vary
        thisdate = str(df.keys()[cell])[:10]
        #store the measure in that column too - as it's the total
      if measure == 'Number of patients who no longer meet the criteria to reside':
        nolongermeetcriteria = numberofpatients
      #we add a test that it's not '-', i.e. a string
      #print("IS IT ZERO",nolongermeetcriteria)
      if type(nolongermeetcriteria) != str:
        #we check that the total patients is not zero, which would cause an error
        if nolongermeetcriteria != 0:
          print("NOT ZERO")
          #calculate the patients as a percentage of the total no longer meeting the criteria
          percof = int(numberofpatients)/int(nolongermeetcriteria)
        #if if is zero or '-' then we store the lack of data
      else:
        print("ZERO")
        percof = 'no data'
      #print("thisdate",thisdate)
      #store all of that in the dict
      record['region'] = region
      record['code'] = stpcode
      record['org'] = stpname
      record['date'] = thisdate
      record['measure'] = measure
      record['numberofpatients'] = numberofpatients
      #extra column showing figures as percentages
      record['percof_nolongermeetcriteria'] = percof
      print(record)
      #add to the list
      rows_list.append(record)
      #print("rows_list",rows_list)

#create a dataframe from that list of dicts
reshapeddf = pd.DataFrame(rows_list)
# Out:
# Streaming output truncated to the last 5000 lines.
<class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-28', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 273, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 72 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-28', 'measure': 'Number of patients discharged', 'numberofpatients': 72, 'percof_nolongermeetcriteria': 0.26373626373626374}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 201 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-28', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 201, 'percof_nolongermeetcriteria': 0.7362637362637363}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 277 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-29', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 277, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 86 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-29', 'measure': 'Number of patients discharged', 'numberofpatients': 86, 'percof_nolongermeetcriteria': 0.3104693140794224}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 191 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-29', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 191, 'percof_nolongermeetcriteria': 0.6895306859205776}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 282 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 282, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 66 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-30', 'measure': 'Number of patients discharged', 'numberofpatients': 66, 'percof_nolongermeetcriteria': 0.23404255319148937}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 216 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-04-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 216, 'percof_nolongermeetcriteria': 0.7659574468085106}

# %% [markdown]
# ## Export as a CSV

# %%
reshapeddf.to_csv("reshapeddf.csv")

# %% [markdown]
# ## Scrape the other spreadsheet URLs
#
# Now we need to fetch all of the spreadsheets, so we need to scrape the sitreps page. For this scraper code I've used ChatGPT with the prompt:
#
# > *Write a Python script that uses BeautifulSoup to fetch all the links to XLSX files on the webpage https://www.england.nhs.uk/statistics/statistical-work-areas/discharge-delays-acute-data/, and stores them in a list*
#
# I've added my own comments below explaining what the code does.

# %%
#store the URL
url = 'https://www.england.nhs.uk/statistics/statistical-work-areas/discharge-delays-acute-data/'
#fetch the page at that URL
response = requests.get(url)
#convert it into a soup object
soup = BeautifulSoup(response.content, 'html.parser')
#create an empty list
xlsx_links = []
#grab all the <a> tags and loop through them
for link in soup.find_all('a'):
  #grab the href= attribute
    href = link.get('href')
    #if it ends with .xlsx
    if href and href.endswith('.xlsx'):
      #add it to the list
        xlsx_links.append(href)

#check how long that is - it should be 17 months
print(len(xlsx_links))
# Out:
# 17

# %% [markdown]
# We can print each one to see if they cover all the months we'd expect.

# %%
#loop through the links captured
for i in xlsx_links:
  #print each one
  print(i)
# Out:
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-April2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-May2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-June2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-July2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-August2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-September2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-October2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-November2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-December2022-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-January2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-February2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-March2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-April2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-May2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-June2023-revised.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-monthly-data-webfile-July2023.xlsx
# https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2023/08/Daily-discharge-sitrep-timeseries-data-webfile-April2021-July2023.xlsx

# %% [markdown]
# ### Remove the extra file
#
# At the end there's an extra file that covers from April 2021 onwards but it's at the national level with no local breakdown. We need to remove that from the list.

# %%
#replace the list with the same list,
#but only up to (and not including) the last item
xlsx_links = xlsx_links[:-1]

# %% [markdown]
# ## Store in some functions
#
# Now we know it works we can store in a function and call that on multiple CSV files. First, we need a function to fetch and clean the XLSX.
#
# If we try this on the second spreadsheet we encounter a problem: the rows aren't always in the same place.

# %%
#read in the sheet called 'Table 2', skipping the first 3 rows
#see https://stackoverflow.com/questions/35400861/pandas-read-table-usecols-error-with on how to specify a range of cols
df = pd.read_excel(xlsx_links[1], skiprows = 3, sheet_name = 'Table 2')
df
# Out:
#      Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0           NaN  Notes: \n1. Due to disclosure risks, trust-lev...        NaN
# 1           NaN                                                NaN        NaN
# 2           NaN                                                NaN        NaN
# 3           NaN                                                NaN        NaN
# 4           NaN                                                NaN        NaN
# ..          ...                                                ...        ...
# 171         NaN                                         SOUTH WEST        RK9
# 172         NaN                                         SOUTH WEST        RN3
# 173         NaN                                         SOUTH WEST        RNZ
# 174         NaN                                         SOUTH WEST        RTE
# 175         NaN                                         SOUTH WEST        RVJ
#
#                                          Unnamed: 3  \
# 0                                               NaN
# 1                           ENGLAND (Type 1 Trusts)
# 2                                   EAST OF ENGLAND
# 3                                            LONDON
# 4                                          MIDLANDS
# ..                                              ...
# 171         UNIVERSITY HOSPITALS PLYMOUTH NHS TRUST
# 172    GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST
# 173                  SALISBURY NHS FOUNDATION TRUST
# 174  GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST
# 175                         NORTH BRISTOL NHS TRUST
#
#                                    2022-05-01 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                20155
# 2                                                 2070
# 3                                                 2139
# 4                                                 3219
# ..                                                 ...
# 171                                                233
# 172                                                168
# 173                                                140
# 174                                                321
# 175                                                268
#
#                         Unnamed: 5  \
# 0    Number of patients discharged
# 1                             7575
# 2                              828
# 3                             1055
# 4                             1291
# ..                             ...
# 171                            121
# 172                             56
# 173                             38
# 174                            103
# 175                             62
#
#                                             Unnamed: 6  \
# 0    Number of patients remaining in hospital who n...
# 1                                                12580
# 2                                                 1242
# 3                                                 1084
# 4                                                 1928
# ..                                                 ...
# 171                                                112
# 172                                                112
# 173                                                102
# 174                                                218
# 175                                                206
#
#                                    2022-05-02 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                18686
# 2                                                 1911
# 3                                                 1937
# 4                                                 3225
# ..                                                 ...
# 171                                                182
# 172                                                161
# 173                                                117
# 174                                                272
# 175                                                266
#
#                         Unnamed: 8  \
# 0    Number of patients discharged
# 1                             6192
# 2                              613
# 3                              849
# 4                             1231
# ..                             ...
# 171                             75
# 172                             52
# 173                             22
# 174                             65
# 175                             64
#
#                                             Unnamed: 9  ...  \
# 0    Number of patients remaining in hospital who n...  ...
# 1                                                12494  ...
# 2                                                 1298  ...
# 3                                                 1088  ...
# 4                                                 1994  ...
# ..                                                 ...  ...
# 171                                                107  ...
# 172                                                109  ...
# 173                                                 95  ...
# 174                                                207  ...
# 175                                                202  ...
#
#                                            Unnamed: 87  \
# 0    Number of patients remaining in hospital who n...
# 1                                                11927
# 2                                                 1132
# 3                                                 1084
# 4                                                 1898
# ..                                                 ...
# 171                                                124
# 172                                                102
# 173                                                 83
# 174                                                200
# 175                                                233
#
#                                    2022-05-29 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                18492
# 2                                                 1804
# 3                                                 2268
# 4                                                 3080
# ..                                                 ...
# 171                                                196
# 172                                                173
# 173                                                110
# 174                                                252
# 175                                                284
#
#                        Unnamed: 89  \
# 0    Number of patients discharged
# 1                             7038
# 2                              693
# 3                             1109
# 4                             1349
# ..                             ...
# 171                             78
# 172                             64
# 173                             30
# 174                             59
# 175                             74
#
#                                            Unnamed: 90  \
# 0    Number of patients remaining in hospital who n...
# 1                                                11454
# 2                                                 1111
# 3                                                 1159
# 4                                                 1731
# ..                                                 ...
# 171                                                118
# 172                                                109
# 173                                                 80
# 174                                                193
# 175                                                210
#
#                                    2022-05-30 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                17095
# 2                                                 1865
# 3                                                 1892
# 4                                                 2815
# ..                                                 ...
# 171                                                179
# 172                                                171
# 173                                                 85
# 174                                                246
# 175                                                278
#
#                        Unnamed: 92  \
# 0    Number of patients discharged
# 1                             5441
# 2                              614
# 3                              738
# 4                             1060
# ..                             ...
# 171                             60
# 172                             64
# 173                             17
# 174                             55
# 175                             77
#
#                                            Unnamed: 93  \
# 0    Number of patients remaining in hospital who n...
# 1                                                11654
# 2                                                 1251
# 3                                                 1154
# 4                                                 1755
# ..                                                 ...
# 171                                                119
# 172                                                107
# 173                                                 68
# 174                                                191
# 175                                                201
#
#                                    2022-05-31 00:00:00  \
# 0    Number of patients who no longer meet the crit...
# 1                                                20910
# 2                                                 2094
# 3                                                 2429
# 4                                                 3472
# ..                                                 ...
# 171                                                234
# 172                                                202
# 173                                                125
# 174                                                252
# 175                                                278
#
#                        Unnamed: 95  \
# 0    Number of patients discharged
# 1                             9237
# 2                             1092
# 3                             1309
# 4                             1594
# ..                             ...
# 171                            106
# 172                             95
# 173                             47
# 174                             75
# 175                             74
#
#                                            Unnamed: 96
# 0    Number of patients remaining in hospital who n...
# 1                                                11673
# 2                                                 1002
# 3                                                 1120
# 4                                                 1878
# ..                                                 ...
# 171                                                128
# 172                                                107
# 173                                                 78
# 174                                                177
# 175                                                204
#
# [176 rows x 97 columns]

# %% [markdown]
# We need to identify which row has the second headers in, in order to identify which ones to remove.

# %%
#loop through 10 indices
for i in range(0,10):
  #fetch the cell in column 4 at that position
  thiscell = df[df.keys()[4]][i]
  #and print
  print(thiscell)
  #if it is the headin we want
  if thiscell == 'Number of patients who no longer meet the criteria to reside':
    #store the index
    second_header_row = i
    print("The headers are on row ", second_header_row)
# Out:
# Number of patients who no longer meet the criteria to reside
# The headers are on row  0
# 20155
# 2070
# 2139
# 3219
# 3890
# 3224
# 2822
# 2791
# nan

# %%
#let's store the original list of rows to drop
rows_to_drop = [0,1]
#we can now remove from that the second header row if it's one of those
rows_to_drop.remove(second_header_row)
#and check it's worked
rows_to_drop
# Out:
# [1]

# %% [markdown]
# ### Function 1: removing empty rows and columns (`clean_sitreps`)
#
# Now we can add those lines to a function.

# %%
def clean_sitreps(xlsxurl):
  #read in the sheet called 'Table 2', skipping the first 3 rows
  #see https://stackoverflow.com/questions/35400861/pandas-read-table-usecols-error-with on how to specify a range of cols
  df = pd.read_excel(xlsxurl, skiprows = 3, sheet_name = 'Table 2')
  #loop through 10 indices
  for i in range(0,10):
    #fetch the cell in column 4 at that position
    thiscell = df[df.keys()[4]][i]
    #if it is the headin we want
    if thiscell == 'Number of patients who no longer meet the criteria to reside':
      #store the index
      second_header_row = i
      print("The headers are on row ", second_header_row)
  #store a list of rows to drop, ending before the second header row
  rows_to_drop = list(range(0,second_header_row))
  #and use it to drop that row
  df = df.drop(axis = 0, labels = rows_to_drop)
  #drop column 0
  df = df.drop(axis = 1, labels = df.keys()[0])
  #return to whatever called the function
  return(df)

# %% [markdown]
# ### Function 2: reshaping (`reshape_sitreps`)
#
# Next we create a function for the reshaping.

# %%
#define a new function that does all the cleaning
def reshape_sitreps(df):
  #create an empty list to store a list of dicts
  rows_list = []
  #loop through each row, starting from row 12 because that's where the STP data begins
  for i in range(11,len(df)):
    #print(i)
    #print(df.iloc[i][2])
    #the first, second and third cell should have the region, STP code and name
    #store each of those
    region = df.iloc[i][0]
    stpcode = df.iloc[i][1]
    stpname = df.iloc[i][2]
    #if it's not an empty cell or header cell
    #print("region", region)
    if region != "Region" and not pd.isna(region):
      #loop through the indices for the other 124 cells in the row
      for cell in range(3,len(df.iloc[0])):
        #start with an empty dict
        record = {}
        #print("cell", cell)
        print("measure", df.iloc[0][cell])
        #store the row 1 heading at that position showing the measure
        measure = df.iloc[0][cell]
        print("numofpatients", df.iloc[i][cell], type(df.iloc[i][cell]))
        #store the value in the cell related to that measure
        numberofpatients = df.iloc[i][cell]
        #print("col", df.keys()[cell])
        #If the column heading - the key - *doesn't* begin with 'Unnamed'
        if str(df.keys()[cell])[:7] != "Unnamed":
          #store it, because it will be the date
          #extract the first 10 chars because the others vary
          thisdate = str(df.keys()[cell])[:10]
          #store the measure in that column too - as it's the total
        if measure == 'Number of patients who no longer meet the criteria to reside':
          nolongermeetcriteria = numberofpatients
        #we add a test that it's not '-', i.e. a string
        #print("IS IT ZERO",nolongermeetcriteria)
        if type(nolongermeetcriteria) != str:
          #we check that the total patients is not zero, which would cause an error
          if nolongermeetcriteria != 0:
            #print("NOT ZERO")
            #calculate the patients as a percentage of the total no longer meeting the criteria
            percof = int(numberofpatients)/int(nolongermeetcriteria)
        #if if is zero or '-' then we store the lack of data
        else:
          print("ZERO")
          percof = 'no data'
        #print("thisdate",thisdate)
        #store all of that in the dict
        record['region'] = region
        record['code'] = stpcode
        record['org'] = stpname
        record['date'] = thisdate
        record['measure'] = measure
        record['numberofpatients'] = numberofpatients
        #extra column showing figures as percentages
        record['percof_nolongermeetcriteria'] = percof
        print(record)
        #add to the list
        rows_list.append(record)
        #print("rows_list",rows_list)
  #create a dataframe from that list of dicts
  reshapeddf = pd.DataFrame(rows_list)
  #return the dataframe and list of dicts
  return(reshapeddf, rows_list)

# %% [markdown]
# ## Run the functions on our scraped URLs
#
# Now let's try to run those on the list of URLs.

# %%
#create a list
listofdfs = []

#loop through the URLs
for i in xlsx_links:
  #run the cleaning function that grabs the XLSX and cleans it
  cleandf = clean_sitreps(i)
  #use the results with the reshaping function
  df1, list1 = reshape_sitreps(cleandf)
  listofdfs.append(df1)

concatenateddf = pd.concat(listofdfs)
# Out:
# Streaming output truncated to the last 5000 lines.
# numofpatients 86 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-03', 'measure': 'Number of patients discharged', 'numberofpatients': 86, 'percof_nolongermeetcriteria': 0.26299694189602446}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 241 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-03', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 241, 'percof_nolongermeetcriteria': 0.7370030581039755}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 348 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-04', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 348, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 121 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-04', 'measure': 'Number of patients discharged', 'numberofpatients': 121, 'percof_nolongermeetcriteria': 0.34770114942528735}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 227 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-04', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 227, 'percof_nolongermeetcriteria': 0.6522988505747126}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 344 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-05', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 344, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 126 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-05', 'measure': 'Number of patients discharged', 'numberofpatients': 126, 'percof_nolongermeetcriteria': 0.36627906976744184}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 218 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-05', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 218, 'percof_nolongermeetcriteria': 0.6337209302325582}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 339 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-06', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 339, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 130 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-06', 'measure': 'Number of patients discharged', 'numberofpatients': 130, 'percof_nolongermeetcriteria': 0.3834808259587021}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 209 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RVV', 'org': 'EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION TRUST', 'date': '2023-07-06', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 209, 'percof_nolongermeetcriteria': 0.616519174041298}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients

# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 109 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-07', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 109, 'percof_nolongermeetcriteria': 0.5422885572139303}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 182 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-08', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 182, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 50 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-08', 'measure': 'Number of patients discharged', 'numberofpatients': 50, 'percof_nolongermeetcriteria': 0.27472527472527475}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 132 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-08', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 132, 'percof_nolongermeetcriteria': 0.7252747252747253}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 163 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-09', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 163, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 36 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-09', 'measure': 'Number of patients discharged', 'numberofpatients': 36, 'percof_nolongermeetcriteria': 0.22085889570552147}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 127 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-09', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 127, 'percof_nolongermeetcriteria': 0.7791411042944786}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 213 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-10', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 213, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 87 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-10', 'measure': 'Number of patients discharged', 'numberofpatients': 87, 'percof_nolongermeetcriteria': 0.4084507042253521}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 126 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-10', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 126, 'percof_nolongermeetcriteria': 0.5915492957746479}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 226 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-11', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 226, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 76 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-11', 'measure': 'Number of patients discharged', 'numberofpatients': 76, 'percof_nolongermeetcriteria': 0.336283185840708}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 150 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-11', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 150, 'percof_nolongermeetcriteria': 0.6637168141592921}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 220 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-12', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 220, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 81 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-12', 'measure': 'Number of patients discharged', 'numberofpatients': 81, 'percof_nolongermeetcriteria': 0.36818181818181817}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 139 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-12', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 139, 'percof_nolongermeetcriteria': 0.6318181818181818}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 253 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-13', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 253, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 82 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-13', 'measure': 'Number of patients discharged', 'numberofpatients': 82, 'percof_nolongermeetcriteria': 0.3241106719367589}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 171 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-13', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 171, 'percof_nolongermeetcriteria': 0.6758893280632411}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 265 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-14', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 265, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 103 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-14', 'measure': 'Number of patients discharged', 'numberofpatients': 103, 'percof_nolongermeetcriteria': 0.3886792452830189}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 162 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-14', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 162, 'percof_nolongermeetcriteria': 0.6113207547169811}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 225 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-15', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 225, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 50 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-15', 'measure': 'Number of patients discharged', 'numberofpatients': 50, 'percof_nolongermeetcriteria': 0.2222222222222222}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 175 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-15', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 175, 'percof_nolongermeetcriteria': 0.7777777777777778}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 202 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-16', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 202, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 43 <class 'int'>
# {'region': 'SOUTH EAST', 'code': 'RWF', 'org': 'MAIDSTONE AND TUNBRIDGE WELLS NHS TRUST', 'date': '2023-07-16', 'measure': 'Number of patients discharged', 'numberofpatients': 43, 'percof_nolongermeetcriteria': 0.21287128712871287}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 159 <class 'int'>
# ...
# measure Number of patients discharged
# numofpatients 50 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-16', 'measure': 'Number of patients discharged', 'numberofpatients': 50, 'percof_nolongermeetcriteria': 0.19230769230769232}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 210 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-16', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 210, 'percof_nolongermeetcriteria': 0.8076923076923077}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 317 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-17', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 99 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-17', 'measure': 'Number of patients discharged', 'numberofpatients': 99, 'percof_nolongermeetcriteria': 0.31230283911671924}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 218 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-17', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 218, 'percof_nolongermeetcriteria': 0.6876971608832808}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 317 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-18', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 317, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 95 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-18', 'measure': 'Number of patients discharged', 'numberofpatients': 95, 'percof_nolongermeetcriteria': 0.2996845425867508}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 222 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-18', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 222, 'percof_nolongermeetcriteria': 0.7003154574132492}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 319 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-19', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 319, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 80 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-19', 'measure': 'Number of patients discharged', 'numberofpatients': 80, 'percof_nolongermeetcriteria': 0.2507836990595611}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 239 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-19', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 239, 'percof_nolongermeetcriteria': 0.7492163009404389}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 352 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-20', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 352, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 121 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-20', 'measure': 'Number of patients discharged', 'numberofpatients': 121, 'percof_nolongermeetcriteria': 0.34375}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 231 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-20', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 231, 'percof_nolongermeetcriteria': 0.65625}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 366 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-21', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 366, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 121 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-21', 'measure': 'Number of patients discharged', 'numberofpatients': 121, 'percof_nolongermeetcriteria': 0.33060109289617484}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 245 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-21', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 245, 'percof_nolongermeetcriteria': 0.6693989071038251}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 303 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-22', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 303, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 68 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-22', 'measure': 'Number of patients discharged', 'numberofpatients': 68, 'percof_nolongermeetcriteria': 0.22442244224422442}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 235 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-22', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 235, 'percof_nolongermeetcriteria': 0.7755775577557755}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 305 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-23', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 305, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 74 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-23', 'measure': 'Number of patients discharged', 'numberofpatients': 74, 'percof_nolongermeetcriteria': 0.24262295081967214}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 231 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-23', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 231, 'percof_nolongermeetcriteria': 0.7573770491803279}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 353 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-24', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 353, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 102 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-24', 'measure': 'Number of patients discharged', 'numberofpatients': 102, 'percof_nolongermeetcriteria': 0.28895184135977336}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 251 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-24', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 251, 'percof_nolongermeetcriteria': 0.7110481586402266}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 366 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-25', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 366, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 111 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-25', 'measure': 'Number of patients discharged', 'numberofpatients': 111, 'percof_nolongermeetcriteria': 0.30327868852459017}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 255 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-25', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 255, 'percof_nolongermeetcriteria': 0.6967213114754098}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 368 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-26', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 368, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 121 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-26', 'measure': 'Number of patients discharged', 'numberofpatients': 121, 'percof_nolongermeetcriteria': 0.328804347826087}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 247 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-26', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 247, 'percof_nolongermeetcriteria': 0.6711956521739131}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 364 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-27', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 364, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 118 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-27', 'measure': 'Number of patients discharged', 'numberofpatients': 118, 'percof_nolongermeetcriteria': 0.3241758241758242}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 246 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-27', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 246, 'percof_nolongermeetcriteria': 0.6758241758241759}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 392 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-28', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 392, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 149 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-28', 'measure': 'Number of patients discharged', 'numberofpatients': 149, 'percof_nolongermeetcriteria': 0.38010204081632654}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 243 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-28', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 243, 'percof_nolongermeetcriteria': 0.6198979591836735}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 307 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-29', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 307, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 78 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-29', 'measure': 'Number of patients discharged', 'numberofpatients': 78, 'percof_nolongermeetcriteria': 0.254071661237785}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 229 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-29', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 229, 'percof_nolongermeetcriteria': 0.745928338762215}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 267 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 267, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 46 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-30', 'measure': 'Number of patients discharged', 'numberofpatients': 46, 'percof_nolongermeetcriteria': 0.17228464419475656}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 221 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 221, 'percof_nolongermeetcriteria': 0.8277153558052435}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 333 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-31', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 333, 'percof_nolongermeetcriteria': 1.0}
# measure Number of patients discharged
# numofpatients 103 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-31', 'measure': 'Number of patients discharged', 'numberofpatients': 103, 'percof_nolongermeetcriteria': 0.30930930930930933}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 230 <class 'int'>
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2023-07-31', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 230, 'percof_nolongermeetcriteria': 0.6906906906906907}

# %% [markdown]
# ### Adapt the `reshape_sitreps` function to deal with notes (no longer needed)
#
# In the June data in the release before the revisions the function broke with this error:
#
# `ValueError: cannot convert float NaN to integer`
#
# The line of code causing that is this:
#
# `percof = int(numberofpatients)/int(nolongermeetcriteria)`
#
# We can also see in the printed lines, this:
#
# `numofpatients nan <class 'float'>`
#
# ...where before it was a number.
#
# And in a previous line:
#
# `region Note: No data are available for 19th June 2022 due to a data collection error.`
#
# This isn't what we're expecting (a region), and checking that spreadsheet shows that this line has a note and no data in the other cells, which is where the `NaN` would come from (and when it tries to convert that to an integer, it generates the error).
#
# We can add another condition to the initial `if` statement which only loops through the cells if the STP name column has a string in it:
#
# `if region != "Region" and not pd.isna(region) and isinstance(stpname, str):`
#
# To capture the note we added an `elif` near the end of the code which runs if the STP Name column is empty but the region column is not:
#
# `elif isinstance(stpname, str) is False and isinstance(region, str) is True:`
#
# And we added a final `else` for empty rows.
#
# *Note: this code is now not run*

# %%
#define a new function that does all the cleaning
def reshape_sitreps(df):
  #create an empty list to store a list of dicts
  rows_list = []
  #loop through each row, starting from row 12 because that's where the STP data begins
  for i in range(11,len(df)):
    #print(i)
    #print(df.iloc[i][2])
    #the first, second and third cell should have the region, STP code and name
    #store each of those
    region = df.iloc[i][0]
    stpcode = df.iloc[i][1]
    stpname = df.iloc[i][2]
    #print("region", region)
    #if it's not an empty cell or header cell or notes row OR the STP Name is empty
    if region != "Region" and not pd.isna(region) and isinstance(stpname, str):
      #loop through the indices for the other 124 cells in the row
      for cell in range(3,len(df.iloc[0])):
        #start with an empty dict
        record = {}
        #print("cell", cell)
        #print("measure", df.iloc[0][cell])
        #store the row 1 heading at that position showing the measure
        measure = df.iloc[0][cell]
        #print("numofpatients", df.iloc[i][cell], type(df.iloc[i][cell]))
        #store the value in the cell related to that measure
        numberofpatients = df.iloc[i][cell]
        #print("col", df.keys()[cell])
        #If the column heading - the key - *doesn't* begin with 'Unnamed'
        if str(df.keys()[cell])[:7] != "Unnamed":
          #store it, because it will be the date
          #extract the first 10 chars because the others vary
          thisdate = str(df.keys()[cell])[:10]
          #store the measure in that column too - as it's the total
        if measure == 'Number of patients who no longer meet the criteria to reside':
          nolongermeetcriteria = numberofpatients
        #we check that the total patients is not zero, which would cause an error
        #print("IS IT ZERO",nolongermeetcriteria)
        if nolongermeetcriteria != 0:
          #print("NOT ZERO")
          #calculate the patients as a percentage of the total no longer meeting the criteria
          percof = int(numberofpatients)/int(nolongermeetcriteria)
        #if if is zero then we store the lack of data
        else:
          #print("ZERO")
          percof = 'no data'
        #print("thisdate",thisdate)
        #store all of that in the dict
        record['region'] = region
        record['code'] = stpcode
        record['org'] = stpname
        record['date'] = thisdate
        record['measure'] = measure
        record['numberofpatients'] = numberofpatients
        #extra column showing figures as percentages
        record['percof_nolongermeetcriteria'] = percof
        #create a note field so it's consistent
        record['note'] = ''
        #print(record)
        #add to the list
        rows_list.append(record)
        #print("rows_list",rows_list)
    #if STP Name is not a string (it's empty because it's a notes row)
    #but the region is a string because it is not empty
    elif isinstance(stpname, str) is False and isinstance(region, str) is True:
      record['region'] = ''
      record['code'] = ''
      record['org'] = ''
      record['date'] = thisdate
      record['measure'] = 'note'
      record['numberofpatients'] = ''
      record['note'] = region
      #extra column showing figures as percentages
      record['percof_nolongermeetcriteria'] = ''
      #print(record)
      #add to the list
      rows_list.append(record)
    #else:
      #print("EMPTY ROW/HEADER ROW")

  #create a dataframe from that list of dicts
  reshapeddf = pd.DataFrame(rows_list)
  #return the dataframe and list of dicts
  return(reshapeddf, rows_list)

# %%
xlsx_links[2]
cleandf = clean_sitreps(xlsx_links[2])
df1, list1 = reshape_sitreps(cleandf)
# Out:
# Streaming output truncated to the last 5000 lines.
# ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-19', 'measure': 'Number of patients discharged by 17:00', 'numberofpatients': 0, 'percof_nolongermeetcriteria': 'no data', 'note': ''}
# measure Number of patients discharged between 17:01 and 23:59
# numofpatients 0 <class 'int'>
# ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-19', 'measure': 'Number of patients discharged between 17:01 and 23:59', 'numberofpatients': 0, 'percof_nolongermeetcriteria': 'no data', 'note': ''}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 0 <class 'int'>
# ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-19', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 0, 'percof_nolongermeetcriteria': 'no data', 'note': ''}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 159 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-20', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 159, 'percof_nolongermeetcriteria': 1.0, 'note': ''}
# measure Number of patients discharged by 17:00
# numofpatients 43 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-20', 'measure': 'Number of patients discharged by 17:00', 'numberofpatients': 43, 'percof_nolongermeetcriteria': 0.27044025157232704, 'note': ''}
# measure Number of patients discharged between 17:01 and 23:59
# numofpatients 11 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-20', 'measure': 'Number of patients discharged between 17:01 and 23:59', 'numberofpatients': 11, 'percof_nolongermeetcriteria': 0.06918238993710692, 'note': ''}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 105 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-20', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 105, 'percof_nolongermeetcriteria': 0.660377358490566, 'note': ''}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 201 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-21', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 201, 'percof_nolongermeetcriteria': 1.0, 'note': ''}
# measure Number of patients discharged by 17:00
# numofpatients 76 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RH5', 'org': 'SOMERSET NHS FOUNDATION TRUST', 'date': '2022-06-21', 'measure': 'Number of patients discharged by 17:00', 'numberofpatients':
 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 186, 'percof_nolongermeetcriteria': 0.7153846153846154, 'note': ''}
# measure Number of patients who no longer meet the criteria to reside
# numofpatients 279 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-06-30', 'measure': 'Number of patients who no longer meet the criteria to reside', 'numberofpatients': 279, 'percof_nolongermeetcriteria': 1.0, 'note': ''}
# measure Number of patients discharged by 17:00
# numofpatients 72 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-06-30', 'measure': 'Number of patients discharged by 17:00', 'numberofpatients': 72, 'percof_nolongermeetcriteria': 0.25806451612903225, 'note': ''}
# measure Number of patients discharged between 17:01 and 23:59
# numofpatients 7 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-06-30', 'measure': 'Number of patients discharged between 17:01 and 23:59', 'numberofpatients': 7, 'percof_nolongermeetcriteria': 0.025089605734767026, 'note': ''}
# measure Number of patients remaining in hospital who no longer meet the criteria to reside
# numofpatients 200 <class 'int'>
# NOT ZERO
# {'region': 'SOUTH WEST', 'code': 'RVJ', 'org': 'NORTH BRISTOL NHS TRUST', 'date': '2022-06-30', 'measure': 'Number of patients remaining in hospital who no longer meet the criteria to reside', 'numberofpatients': 200, 'percof_nolongermeetcriteria': 0.7168458781362007, 'note': ''}
# region nan
# EMPTY ROW/HEADER ROW
# region Note: No data are available for 19th June 2022 due to a data collection error.
# {'region': '', 'code': '', 'org': '', 'date': '2022-06-30', 'measure': 'note', 'numberofpatients': '', 'percof_nolongermeetcriteria': '', 'note': 'Note: No data are available for 19th June 2022 due to a data collection error.'}

# %% [markdown]
# ## Run the revised function on all URLs (no longer needed)
#
# Now we try that on all the files again.
#
# *Note: this is no longer run*.

# %%
#create a list
listofdfs = []

#loop through the URLs
for i in xlsx_links:
  print('scraping', i)
  #run the cleaning function that grabs the XLSX and cleans it
  cleandf = clean_sitreps(i)
  #use the results with the reshaping function
  df1, list1 = reshape_sitreps(cleandf)
  listofdfs.append(df1)

concatenateddf = pd.concat(listofdfs)

# %% [markdown]
# ## Export the combined dataframe as a CSV
#
# Once done, we can export to the Files area.

# %%
concatenateddf.to_csv("concatenateddf.csv")

# %%
#import a library for file downloads in Colab
from google.colab import files
#start a file download of that CSV
files.download("concatenateddf.csv")

# %% [markdown]
# ## Quality checking
#
# We can quality check in Excel, but let's do some basic checking here.

# %%
#remind ourselves what the column headings (keys) are
concatenateddf.keys()
# Out:
# Index(['region', 'code', 'org', 'date', 'measure', 'numberofpatients',
#        'percof_nolongermeetcriteria'],
#       dtype='object')

# %% [markdown]
# There should only be three measures, for example. And there should be the same number of values for each.
#
# *Note: previously there were were
# four measures, with discharges split between 'Those discharged between 1700 and 2359' and 'Those discharged before 1700'. This level of detail is not available in the revised data.*

# %%
#how many of each measure
concatenateddf['measure'].value_counts()
# Out:
# Number of patients who no longer meet the criteria to reside                          79228
# Number of patients discharged                                                         79228
# Number of patients remaining in hospital who no longer meet the criteria to reside    79228
# Name: measure, dtype: int64

# %% [markdown]
# ### No longer needed: Cleaning auto-incremented numbers
#
# In the previous April spreadsheet we could see that someone has copied values across columns but not realised that Excel's auto-formatting has incremented the numbers each time. We needed to clean that.
#
# We used regex and the `.sub()` function to do this.
#
# *Note: no longer used*.

# %%
#store an example of a string we need to fix
teststr = 'Number of patients discharged between 17:01 and 23:70'
#test the regex to replace the mistake - 23: followed by two digits - with 23:59
re.sub('23:[0-9]{2}', '23:59', teststr)
# Out:
# 'Number of patients discharged between 17:01 and 23:59'

# %%
#store an example of the other string we need to fix
teststr = 'Number of patients discharged by 17:00'
#test the regex to replace the mistake - 17: followed by two digits - with 17:00
#we need the text before it too, otherwise we'd end up replacing 17:01 in the other string
re.sub('discharged by 17:[0-9]{2}', 'discharged by 17:00', teststr)
# Out:
# 'Number of patients discharged by 17:00'

# %% [markdown]
# Once we've got the right regex, we clean the whole column.

# %%
#apply that to all the values in the column
cleanmeasures1 = [re.sub('discharged by 17:[0-9]{2}', 'discharged by 17:00', i) for i in concatenateddf['measure']]
#check the results - we have to convert to a pandas Series to apply value_counts()
pd.Series(cleanmeasures1).value_counts()
# Out:
# Number of patients who no longer meet the criteria to reside                          69407
# Number of patients discharged by 17:00                                                69407
# Number of patients remaining in hospital who no longer meet the criteria to reside    69406
# Number of patients discharged between 17:01 and 23:59                                 64843
# Number of patients discharged between 17:01 and 23:81                                   163
# Number of patients discharged between 17:01 and 23:76                                   163
# Number of patients discharged between 17:01 and 23:77                                   163
# Number of patients discharged between 17:01 and 23:78                                   163
# Number of patients discharged between 17:01 and 23:79                                   163
# Number of patients discharged between 17:01 and 23:80                                   163
# Number of patients discharged between 17:01 and 23:82                                   163
# Number of patients discharged between 17:01 and 23:74                                   163
# Number of patients discharged between 17:01 and 23:83                                   163
# Number of patients discharged between 17:01 and 23:84                                   163
# Number of patients discharged between 17:01 and 23:85                                   163
# Number of patients discharged between 17:01 and 23:86                                   163
# Number of patients discharged between 17:01 and 23:87                                   163
# Number of patients discharged between 17:01 and 23:75                                   163
# Number of patients discharged between 17:01 and 23:72                                   163
# Number of patients discharged between 17:01 and 23:73                                   163
# Number of patients discharged between 17:01 and 23:71                                   163
# Number of patients discharged between 17:01 and 23:70                                   163
# Number of patients discharged between 17:01 and 23:69                                   163
# Number of patients discharged between 17:01 and 23:68                                   163
# Number of patients discharged between 17:01 and 23:67                                   163
# Number of patients discharged between 17:01 and 23:66                                   163
# Number of patients discharged between 17:01 and 23:65                                   163
# Number of patients discharged between 17:01 and 23:64                                   163
# Number of patients discharged between 17:01 and 23:63                                   163
# Number of patients discharged between 17:01 and 23:62                                   163
# Number of patients discharged between 17:01 and 23:61                                   163
# Number of patients discharged between 17:01 and 23:60                                   163
# note                                                                                      2
# dtype: int64

# %% [markdown]
# That's fixed one. Now for the other.

# %%
#apply that to all the values in the half-cleaned list
cleanmeasures2 = [re.sub('23:[0-9]{2}', '23:59', i) for i in cleanmeasures1]
#check the results - we have to convert to a pandas Series to apply value_counts()
pd.Series(cleanmeasures2).value_counts()
# Out:
# Number of patients who no longer meet the criteria to reside                          69407
# Number of patients discharged by 17:00                                                69407
# Number of patients discharged between 17:01 and 23:59                                 69407
# Number of patients remaining in hospital who no longer meet the criteria to reside    69406
# note                                                                                      2
# dtype: int64

# %% [markdown]
# Now to add it back to the dataframe. We could overwrite the original column but we are going to add it as a 'clean version' so the two can be compared and checked.

# %%
#create a new column in the dataframe, and assign the list of cleaned measures
concatenateddf['measure_cleaned'] = cleanmeasures2
#check
concatenateddf['measure_cleaned'].value_counts()
# Out:
# Number of patients who no longer meet the criteria to reside                          69407
# Number of patients discharged by 17:00                                                69407
# Number of patients discharged between 17:01 and 23:59                                 69407
# Number of patients remaining in hospital who no longer meet the criteria to reside    69406
# note                                                                                      2
# Name: measure_cleaned, dtype: int64

# %% [markdown]
# ## Export cleaned version
#
# We repeat the code from earlier.

# %%
concatenateddf.to_csv("concatenateddf.csv")
#import a library for file downloads in Colab
from google.colab import files
#start a file download of that CSV
files.download("concatenateddf.csv")

# %% [markdown]
# ## Add week numbers and days
#
# We can add week numbers and weekdays in a spreadsheet by using the `WEEKNUM` and `TEXT` functions, but let's try to do it here.
#
# [This Stackoverflow thread](https://stackoverflow.com/questions/31181295/converting-a-pandas-date-to-week-number) explains how to get the week number using `.dt.isocalendar().week` and [this one](https://stackoverflow.com/questions/30222533/create-a-day-of-week-column-in-a-pandas-dataframe-using-python) points to `.dt.day_name()` for grabbing the weekday.
#
# However, we need to check if our dates are in datetime format - and they're not.

# %%
#loop through the first 10 items in the date column
for i in concatenateddf.date[:10]:
  #print the item, and the type
  print(i, type(i))
# Out:
# 2022-04-01 <class 'str'>
# 2022-04-01 <class 'str'>
# 2022-04-01 <class 'str'>
# 2022-04-02 <class 'str'>
# 2022-04-02 <class 'str'>
# 2022-04-02 <class 'str'>
# 2022-04-03 <class 'str'>
# 2022-04-03 <class 'str'>
# 2022-04-03 <class 'str'>
# 2022-04-04 <class 'str'>

# %% [markdown]
# We can convert those strings using the `.to_datetime()` function in pandas.

# %%
#loop through the first 3
for i in concatenateddf.date[:3]:
  #apply .to_datetime() and print
  print(pd.to_datetime(i))
# Out:
# 2022-04-01 00:00:00
# 2022-04-01 00:00:00
# 2022-04-01 00:00:00

# %%
#create a list by doing this for all items
datetimecolumn = [pd.to_datetime(i) for i in concatenateddf.date]
#check the length of that list
len(datetimecolumn) == len(concatenateddf)
# Out:
# True

# %%
#check it's the same length as the dataframe
len(datetimecolumn) == len(concatenateddf)
# Out:
# True

# %%
#add to the dataframe
concatenateddf['datetime'] = datetimecolumn

# %%
#add a weeknum column
concatenateddf['weeknum'] = concatenateddf['datetime'].dt.isocalendar().week
#add a weekday column
concatenateddf['weekday'] = concatenateddf['datetime'].dt.day_name()
#add a year column
concatenateddf['year'] = concatenateddf['datetime'].dt.year

# %% [markdown]
# ### Add a year-weeknum column
#
# Because some week numbers appear twice, we want to create a column where they are combined with years to identify which year they belong to (and sort appropriately).
#
# To do this we need to convert both to strings, and also prefix the week numbers with a zero where they are one digit (so that they will sort properly).

# %%
#create an empty list
weeknumstr = []
#convert weeknum into a string with a 0 prefix if needed for sorting
for i in concatenateddf['weeknum']:
  if(i < 10):
    i = '0'+str(i)
  else:
    i = str(i)
  weeknumstr.append(i)
#check the length
len(weeknumstr)
# Out:
# 237684

# %%
#create a list of year strings
yrstr = [str(i) for i in concatenateddf['year']]
#check the length
len(yrstr)
# Out:
# 237684

# %%
#create an empty list
yr_weeknumlist = []
#loop through a list of indices
for i in range(0,len(yrstr)):
  #add to that list the year-weeknum string at each index
  yr_weeknumlist.append(yrstr[i]+weeknumstr[i])

len(yr_weeknumlist)
# Out:
# 237684

# %%
#add to the dataframe
concatenateddf['yr_weeknum'] = yr_weeknumlist

# %%
concatenateddf
# Out:
#                 region code  \
# 0      EAST OF ENGLAND  QUE
# 1      EAST OF ENGLAND  QUE
# 2      EAST OF ENGLAND  QUE
# 3      EAST OF ENGLAND  QUE
# 4      EAST OF ENGLAND  QUE
# ...                ...  ...
# 14968       SOUTH WEST  RVJ
# 14969       SOUTH WEST  RVJ
# 14970       SOUTH WEST  RVJ
# 14971       SOUTH WEST  RVJ
# 14972       SOUTH WEST  RVJ
#
#                                                      org        date  \
# 0      NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 1      NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 2      NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 3      NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# 4      NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# ...                                                  ...         ...
# 14968                            NORTH BRISTOL NHS TRUST  2023-07-30
# 14969                            NORTH BRISTOL NHS TRUST  2023-07-30
# 14970                            NORTH BRISTOL NHS TRUST  2023-07-31
# 14971                            NORTH BRISTOL NHS TRUST  2023-07-31
# 14972                            NORTH BRISTOL NHS TRUST  2023-07-31
#
#                                                  measure numberofpatients  \
# 0      Number of patients who no longer meet the crit...              426
# 1                          Number of patients discharged              230
# 2      Number of patients remaining in hospital who n...              196
# 3      Number of patients who no longer meet the crit...              440
# 4                          Number of patients discharged              208
# ...                                                  ...              ...
# 14968                      Number of patients discharged               46
# 14969  Number of patients remaining in hospital who n...              221
# 14970  Number of patients who no longer meet the crit...              333
# 14971                      Number of patients discharged              103
# 14972  Number of patients remaining in hospital who n...              230
#
#       percof_nolongermeetcriteria   datetime  weeknum   weekday  year  \
# 0                             1.0 2022-04-01       13    Friday  2022
# 1                        0.539906 2022-04-01       13    Friday  2022
# 2                        0.460094 2022-04-01       13    Friday  2022
# 3                             1.0 2022-04-02       13  Saturday  2022
# 4                        0.472727 2022-04-02       13  Saturday  2022
# ...                           ...        ...      ...       ...   ...
# 14968                    0.172285 2023-07-30       30    Sunday  2023
# 14969                    0.827715 2023-07-30       30    Sunday  2023
# 14970                         1.0 2023-07-31       31    Monday  2023
# 14971                    0.309309 2023-07-31       31    Monday  2023
# 14972                    0.690691 2023-07-31       31    Monday  2023
#
#       yr_weeknum
# 0         202213
# 1         202213
# 2         202213
# 3         202213
# 4         202213
# ...          ...
# 14968     202330
# 14969     202330
# 14970     202331
# 14971     202331
# 14972     202331
#
# [237684 rows x 12 columns]

# %% [markdown]
# ### ***NOTE: Week 52 is split between years***
#
# When quality checking this data in a spreadsheet, one quirk becomes apparent: Sunday January 1 2023 is week 52 - officially the last week of 2022. But of course the year is not 2022. As a result it needs cleaning.

# %%
#replace any instances of 202352 with 202252
concatenateddf['yr_weeknum'] = [i.replace('202352','202252') for i in concatenateddf['yr_weeknum']]

# %% [markdown]
# ## Export version with week numbers and days

# %%
concatenateddf.to_csv("concatenateddf.csv")
#import a library for file downloads in Colab
from google.colab import files
#start a file download of that CSV
files.download("concatenateddf.csv")

# %% [markdown]
# ## Filter out the STP
#
# This has made the file a lot larger. We can make it smaller by filtering out the STPs (we only want to look at the trusts).

# %%
#we have published a lookup list of STPs and trusts
lookupurl = "https://docs.google.com/spreadsheets/d/e/2PACX-1vTAJFNix2fyEcqrAj08mYzvG8tHr6xVsMklKRnXRdO6cPDZHuPcSePbSZDaq_MFvXo3K3TSBNZLyiXM/pub?gid=389189088&single=true&output=csv"
lookupdf = pd.read_csv(lookupurl)
lookupdf
# Out:
#               Region STP Code  \
# 0    EAST OF ENGLAND      QUE
# 1    EAST OF ENGLAND      QMM
# 2    EAST OF ENGLAND      QJG
# 3    EAST OF ENGLAND      QHG
# 4    EAST OF ENGLAND      QM7
# ..               ...      ...
# 158       SOUTH WEST      RK9
# 159       SOUTH WEST      RN3
# 160       SOUTH WEST      RNZ
# 161       SOUTH WEST      RTE
# 162       SOUTH WEST      RVJ
#
#                                         STP/org Name   Type
# 0                    CAMBRIDGESHIRE AND PETERBOROUGH    STP
# 1    NORFOLK AND WAVENEY HEALTH AND CARE PARTNERSHIP    STP
# 2                       SUFFOLK AND NORTH EAST ESSEX    STP
# 3              BEDFORDSHIRE, LUTON AND MILTON KEYNES    STP
# 4                       HERTFORDSHIRE AND WEST ESSEX    STP
# ..                                               ...    ...
# 158          UNIVERSITY HOSPITALS PLYMOUTH NHS TRUST  TRUST
# 159     GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST  TRUST
# 160                   SALISBURY NHS FOUNDATION TRUST  TRUST
# 161   GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST  TRUST
# 162                          NORTH BRISTOL NHS TRUST  TRUST
#
# [163 rows x 4 columns]

# %%
concatenateddf.keys()
# Out:
# Index(['region', 'code', 'org', 'date', 'measure', 'numberofpatients',
#        'percof_nolongermeetcriteria', 'datetime', 'weeknum', 'weekday', 'year',
#        'yr_weeknum'],
#       dtype='object')

# %%
#merge the dataframes on the code column
mergeddf = concatenateddf.merge(lookupdf, left_on = 'code', right_on = 'STP Code', how = 'left')
mergeddf
# Out:
#                  region code  \
# 0       EAST OF ENGLAND  QUE
# 1       EAST OF ENGLAND  QUE
# 2       EAST OF ENGLAND  QUE
# 3       EAST OF ENGLAND  QUE
# 4       EAST OF ENGLAND  QUE
# ...                 ...  ...
# 237679       SOUTH WEST  RVJ
# 237680       SOUTH WEST  RVJ
# 237681       SOUTH WEST  RVJ
# 237682       SOUTH WEST  RVJ
# 237683       SOUTH WEST  RVJ
#
#                                                       org        date  \
# 0       NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 1       NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 2       NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-01
# 3       NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# 4       NHS CAMBRIDGESHIRE AND PETERBOROUGH INTEGRATED...  2022-04-02
# ...                                                   ...         ...
# 237679                            NORTH BRISTOL NHS TRUST  2023-07-30
# 237680                            NORTH BRISTOL NHS TRUST  2023-07-30
# 237681                            NORTH BRISTOL NHS TRUST  2023-07-31
# 237682                            NORTH BRISTOL NHS TRUST  2023-07-31
# 237683                            NORTH BRISTOL NHS TRUST  2023-07-31
#
#                                                   measure numberofpatients  \
# 0       Number of patients who no longer meet the crit...              426
# 1                           Number of patients discharged              230
# 2       Number of patients remaining in hospital who n...              196
# 3       Number of patients who no longer meet the crit...              440
# 4                           Number of patients discharged              208
# ...                                                   ...              ...
# 237679                      Number of patients discharged               46
# 237680  Number of patients remaining in hospital who n...              221
# 237681  Number of patients who no longer meet the crit...              333
# 237682                      Number of patients discharged              103
# 237683  Number of patients remaining in hospital who n...              230
#
#        percof_nolongermeetcriteria   datetime  weeknum   weekday  year  \
# 0                              1.0 2022-04-01       13    Friday  2022
# 1                         0.539906 2022-04-01       13    Friday  2022
# 2                         0.460094 2022-04-01       13    Friday  2022
# 3                              1.0 2022-04-02       13  Saturday  2022
# 4                         0.472727 2022-04-02       13  Saturday  2022
# ...                            ...        ...      ...       ...   ...
# 237679                    0.172285 2023-07-30       30    Sunday  2023
# 237680                    0.827715 2023-07-30       30    Sunday  2023
# 237681                         1.0 2023-07-31       31    Monday  2023
# 237682                    0.309309 2023-07-31       31    Monday  2023
# 237683                    0.690691 2023-07-31       31    Monday  2023
#
#        yr_weeknum           Region STP Code                     STP/org Name  \
# 0          202213  EAST OF ENGLAND      QUE  CAMBRIDGESHIRE AND PETERBOROUGH
# 1          202213  EAST OF ENGLAND      QUE  CAMBRIDGESHIRE AND PETERBOROUGH
# 2          202213  EAST OF ENGLAND      QUE  CAMBRIDGESHIRE AND PETERBOROUGH
# 3          202213  EAST OF ENGLAND      QUE  CAMBRIDGESHIRE AND PETERBOROUGH
# 4          202213  EAST OF ENGLAND      QUE  CAMBRIDGESHIRE AND PETERBOROUGH
# ...           ...              ...      ...                              ...
# 237679     202330       SOUTH WEST      RVJ          NORTH BRISTOL NHS TRUST
# 237680     202330       SOUTH WEST      RVJ          NORTH BRISTOL NHS TRUST
# 237681     202331       SOUTH WEST      RVJ          NORTH BRISTOL NHS TRUST
# 237682     202331       SOUTH WEST      RVJ          NORTH BRISTOL NHS TRUST
# 237683     202331       SOUTH WEST      RVJ          NORTH BRISTOL NHS TRUST
#
#          Type
# 0         STP
# 1         STP
# 2         STP
# 3         STP
# 4         STP
# ...       ...
# 237679  TRUST
# 237680  TRUST
# 237681  TRUST
# 237682  TRUST
# 237683  TRUST
#
# [237684 rows x 16 columns]

# %% [markdown]
# ### Drop the STPs
#
# Now we can filter out those where the type is 'trust'.

# %%
#filter where the type is trust
trustsonly = mergeddf[mergeddf['Type'] == 'TRUST']
#check the resulting length
len(trustsonly)
# Out:
# 176322

# %% [markdown]
# ### Drop columns
#
# And drop the columns we no longer need.

# %%
trustsonly.keys()
# Out:
# Index(['region', 'code', 'org', 'date', 'measure', 'numberofpatients',
#        'percof_nolongermeetcriteria', 'datetime', 'weeknum', 'weekday', 'year',
#        'yr_weeknum', 'Region', 'STP Code', 'STP/org Name', 'Type'],
#       dtype='object')

# %%
#drop the columns we don't need
trustsonly = trustsonly.drop(columns = ['Region', 'STP Code', 'STP/org Name', 'Type'])

# %% [markdown]
# ## Export trusts only version

# %%
trustsonly.to_csv("trustsonly.csv")
#import a library for file downloads in Colab
from google.colab import files
#start a file download of that CSV
files.download("trustsonly.csv")
